# %% [markdown]
# # Intro to Python
# ## Módulos
#
# No python, os códigos externos são chamadas de **módulos**, para utilizá-los em seu código, utilize o comando **import**

# %%
import math

A = 16
B = math.sqrt(A)

print(B)
# Out:
# 4.0

# %% [markdown]
# ## Criando DataSets
#
# Com o módulo **pandas** podemos criar estruturas de dados (similares à tabelas) chamadas *dataframes*.

# %%
import pandas as pd

meu_dataset = {
    'carros': ["BMW", "Ford", "Volvo"],
    'passageiros': [5,7,4]
}

df = pd.DataFrame(meu_dataset)
df
# Out:
#   carros  passageiros
# 0    BMW            5
# 1   Ford            7
# 2  Volvo            4

# %%
# Series no pandas são como colunas de tabelas (um array de uma dimensão)

a = [1,7,2]
print(a)

# Podemos ajustar os lables, que por padrão são inteiros e começam em zero.

a = pd.Series(a, index = ["x", "y", "z"])

print(a["y"])

# Podemos usar um objeto key/value, como um dicionário, quando criamos a Serie.

calorias = {"dia 1": 10, "dia 2": 20, "dia 3": 22}

# Para selecionar items específicos, use o argumento index

var = pd.Series(calorias, index = ["dia 1", "dia 3"])
print(var.mean())
# Out:
# [1, 7, 2]
# 7
# 16.0

# %% [markdown]
# ## Importar Datasets
#
# Para importar datasets utilizamos módulo **pandas**. Dataframes são estruturas de duas dimensões, como uma tabela com linhas e colunas.

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('titanic3.csv')
data

# Usamos "loc" para localizar linhas específicas

data.loc[[5]]

# print(pd.options.display.max_rows)
# Out:
#    pclass  survived                 name   sex   age  sibsp  parch ticket  \
# 5       1         1  Anderson, Mr. Harry  male  48.0      0      0  19952
#
#     fare cabin embarked boat  body     home.dest
# 5  26.55   E12        S    3   NaN  New York, NY

# %% [markdown]
# ## Analisando Dataframes

# %%
data.head(5)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
data.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
data.info()

# Temos 1309 linhas, mas a coluna "fare", possui 1308 valores, sendo 1 nulo.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %% [markdown]
# ## Limpando Dados
#
# Removendo linhas com valores em branco

# %%
#Selecionando apenas as 11 primeiras colunas 
df = data.iloc[:,:11]
df_novo = df.dropna()
print(df_novo.info())
df_novo

#Por padrão ele retorna um novo dataframe, se quiser alterar o atual use "inplace  = True"

# Para remover brancos de uma colunas use:df.dropna(subset=['Coluna'], inplace = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 270 entries, 0 to 1231
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    270 non-null    int64
#  1   survived  270 non-null    int64
#  2   name      270 non-null    object
#  3   sex       270 non-null    object
#  4   age       270 non-null    float64
#  5   sibsp     270 non-null    int64
#  6   parch     270 non-null    int64
#  7   ticket    270 non-null    object
#  8   fare      270 non-null    float64
#  9   cabin     270 non-null    object
#  10  embarked  270 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 25.3+ KB
# None
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                                ...
# 1188       3         1  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...
# 1189       3         1                    Sandstrom, Miss. Marguerite Rut
# 1217       3         0         Soholt, Mr. Peter Andreas Lauritz Andersen
# 1230       3         0                         Strom, Miss. Telma Matilda
# 1231       3         0         Strom, Mrs. Wilhelm (Elna Matilda Persson)
#
#          sex    age  sibsp  parch   ticket      fare    cabin embarked
# 0     female  29.00      0      0    24160  211.3375       B5        S
# 1       male   0.92      1      2   113781  151.5500  C22 C26        S
# 2     female   2.00      1      2   113781  151.5500  C22 C26        S
# 3       male  30.00      1      2   113781  151.5500  C22 C26        S
# 4     female  25.00      1      2   113781  151.5500  C22 C26        S
# ...      ...    ...    ...    ...      ...       ...      ...      ...
# 1188  female  24.00      0      2  PP 9549   16.7000       G6        S
# 1189  female   4.00      1      1  PP 9549   16.7000       G6        S
# 1217    male  19.00      0      0   348124    7.6500    F G73        S
# 1230  female   2.00      0      1   347054   10.4625       G6        S
# 1231  female  29.00      1      1   347054   10.4625       G6        S
#
# [270 rows x 11 columns]

# %% [markdown]
# ## Substituindo o valores em branco

# %%
# Substituindo os valores em branco da coluna "fare" por com a média

media = data["fare"].mean()
print(media)
data["fare"].fillna(media, inplace = True)
data["fare"].info()
# Out:
# 33.295479281345564
# <class 'pandas.core.series.Series'>
# RangeIndex: 1309 entries, 0 to 1308
# Series name: fare
# Non-Null Count  Dtype
# --------------  -----
# 1309 non-null   float64
# dtypes: float64(1)
# memory usage: 10.4 KB

# %% [markdown]
# ## Corrigindo Formato

# %%
data["ticket"] = pd.to_numeric(data["ticket"], "coerce")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     957 non-null    float64
#  8   fare       1309 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(4), int64(4), object(6)
# memory usage: 143.3+ KB

# %% [markdown]
# ## Sobrescrevendo Valores

# %%
data.loc[0, "cabin"] = "B6"
data
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch    ticket      fare    cabin embarked boat  \
# 0     female  29.00      0      0   24160.0  211.3375       B6        S    2
# 1       male   0.92      1      2  113781.0  151.5500  C22 C26        S   11
# 2     female   2.00      1      2  113781.0  151.5500  C22 C26        S  NaN
# 3       male  30.00      1      2  113781.0  151.5500  C22 C26        S  NaN
# 4     female  25.00      1      2  113781.0  151.5500  C22 C26        S  NaN
# ...      ...    ...    ...    ...       ...       ...      ...      ...  ...
# 1304  female  14.50      1      0    2665.0   14.4542      NaN        C  NaN
# 1305  female    NaN      1      0    2665.0   14.4542      NaN        C  NaN
# 1306    male  26.50      0      0    2656.0    7.2250      NaN        C  NaN
# 1307    male  27.00      0      0    2670.0    7.2250      NaN        C  NaN
# 1308    male  29.00      0      0  315082.0    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
data
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch    ticket      fare    cabin embarked boat  \
# 0     female  29.00      0      0   24160.0  211.3375       B6        S    2
# 1       male   0.92      1      2  113781.0  151.5500  C22 C26        S   11
# 2     female   2.00      1      2  113781.0  151.5500  C22 C26        S  NaN
# 3       male  30.00      1      2  113781.0  151.5500  C22 C26        S  NaN
# 4     female  25.00      1      2  113781.0  151.5500  C22 C26        S  NaN
# ...      ...    ...    ...    ...       ...       ...      ...      ...  ...
# 1304  female  14.50      1      0    2665.0   14.4542      NaN        C  NaN
# 1305  female    NaN      1      0    2665.0   14.4542      NaN        C  NaN
# 1306    male  26.50      0      0    2656.0    7.2250      NaN        C  NaN
# 1307    male  27.00      0      0    2670.0    7.2250      NaN        C  NaN
# 1308    male  29.00      0      0  315082.0    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
for x in data.index:
    if df.loc[x, "fare"] < 1000:
        df.loc[x, "fare"] = 0.1

data.sort_values(by = ["fare"])
# Out:
#      pclass  survived                                               name  \
# 363       2         0                              Campbell, Mr. William
# 963       3         0                                Leonard, Mr. Lionel
# 125       1         0                                   Fry, Mr. Richard
# 384       2         0                     Cunningham, Mr. Alfred Fleming
# 898       3         0                    Johnson, Mr. William Cahoone Jr
# ..      ...       ...                                                ...
# 114       1         0                     Fortune, Mr. Charles Alexander
# 50        1         1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 183       1         1                             Lesurer, Mr. Gustave J
# 49        1         1                 Cardeza, Mr. Thomas Drake Martinez
# 302       1         1                                   Ward, Miss. Anna
#
#         sex   age  sibsp  parch    ticket      fare        cabin embarked  \
# 363    male   NaN      0      0  239853.0    0.0000          NaN        S
# 963    male  36.0      0      0       NaN    0.0000          NaN        S
# 125    male   NaN      0      0  112058.0    0.0000         B102        S
# 384    male   NaN      0      0  239853.0    0.0000          NaN        S
# 898    male  19.0      0      0       NaN    0.0000          NaN        S
# ..      ...   ...    ...    ...       ...       ...          ...      ...
# 114    male  19.0      3      2   19950.0  263.0000  C23 C25 C27        S
# 50   female  58.0      0      1       NaN  512.3292  B51 B53 B55        C
# 183    male  35.0      0      0       NaN  512.3292         B101        C
# 49     male  36.0      0      1       NaN  512.3292  B51 B53 B55        C
# 302  female  35.0      0      0       NaN  512.3292          NaN        C
#
#     boat  body                                       home.dest
# 363  NaN   NaN                                         Belfast
# 963  NaN   NaN                                             NaN
# 125  NaN   NaN                                             NaN
# 384  NaN   NaN                                         Belfast
# 898  NaN   NaN                                             NaN
# ..   ...   ...                                             ...
# 114  NaN   NaN                                    Winnipeg, MB
# 50     3   NaN                    Germantown, Philadelphia, PA
# 183    3   NaN                                             NaN
# 49     3   NaN  Austria-Hungary / Germantown, Philadelphia, PA
# 302    3   NaN                                             NaN
#
# [1309 rows x 14 columns]
